# %% [markdown]
# # Historic Data Processing

# %% [markdown]
# ## Merging Tables

# %%
from pydoc import describe

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Variaxis (#11)

# %%
col_time = "/SEDE-NL/MANUFACTURA/MAZAK-VARIAXIS-630/IIOT-11/MONITORING/TEMPERATURE/TIMESTAMP"
col_tem = "/SEDE-NL/MANUFACTURA/MAZAK-VARIAXIS-630/IIOT-11/MONITORING/TEMPERATURE/VALUE"
col_hum = "/SEDE-NL/MANUFACTURA/MAZAK-VARIAXIS-630/IIOT-11/MONITORING/HUMIDITY/VALUE"
col_vol = "/SEDE-NL/MANUFACTURA/MAZAK-VARIAXIS-630/IIOT-11/MONITORING/VOLTAGE/VALUE"
col_cor1 = "/SEDE-NL/MANUFACTURA/MAZAK-VARIAXIS-630/IIOT-11/MONITORING/CURRENT_1/VALUE"
col_cor2 = "/SEDE-NL/MANUFACTURA/MAZAK-VARIAXIS-630/IIOT-11/MONITORING/CURRENT_2/VALUE"
col_cor3 = "/SEDE-NL/MANUFACTURA/MAZAK-VARIAXIS-630/IIOT-11/MONITORING/CURRENT_3/VALUE"

nuevas_cols = {col_time : 'Fecha', col_tem : 'Temperatura', col_hum : 'Humedad', col_vol : 'Voltaje',
               col_cor1 : 'Corriente_1', col_cor2: 'Corriente_2', col_cor3 : 'Corriente_3'}

# %%
variaxis_0304 = pd.read_csv('Variaxis/2025-04-03_201.csv', low_memory=False)
variaxis_0304 = variaxis_0304[[col_time, col_tem, col_hum, col_vol, col_cor1, col_cor2, col_cor3]]
variaxis_0304.dropna(inplace = True)

variaxis_1104 = pd.read_csv('Variaxis/2025-04-11_201.csv', low_memory=False)
variaxis_1104 = variaxis_1104[[col_time, col_tem, col_hum, col_vol, col_cor1, col_cor2, col_cor3]]
variaxis_1104.dropna(inplace = True)

variaxis_1404 = pd.read_csv('Variaxis/2025-04-14_201.csv', low_memory=False)
variaxis_1404 = variaxis_1404[[col_time, col_tem, col_hum, col_vol, col_cor1, col_cor2, col_cor3]]
variaxis_1404.dropna(inplace = True)

variaxis_2204 = pd.read_csv('Variaxis/2025-04-22_201.csv', low_memory=False)
variaxis_2204 = variaxis_2204[[col_time, col_tem, col_hum, col_vol, col_cor1, col_cor2, col_cor3]]
variaxis_2204.dropna(inplace = True)

variaxis_3004 = pd.read_csv('Variaxis/2025-04-30_201.csv', low_memory=False)
variaxis_3004 = variaxis_3004[[col_time, col_tem, col_hum, col_vol, col_cor1, col_cor2, col_cor3]]
variaxis_3004.dropna(inplace = True)

variaxis_0805 = pd.read_csv('Variaxis/2025-05-08_201.csv', low_memory=False)
variaxis_0805 = variaxis_0805[[col_time, col_tem, col_hum, col_vol, col_cor1, col_cor2, col_cor3]]
variaxis_0805.dropna(inplace = True)

variaxis_1605 = pd.read_csv('Variaxis/2025-05-16_201.csv', low_memory=False)
variaxis_1605 = variaxis_1605[[col_time, col_tem, col_hum, col_vol, col_cor1, col_cor2, col_cor3]]
variaxis_1605.dropna(inplace = True)

variaxis_1905 = pd.read_csv('Variaxis/2025-05-19_201.csv', low_memory=False)
variaxis_1905 = variaxis_1905[[col_time, col_tem, col_hum, col_vol, col_cor1, col_cor2, col_cor3]]
variaxis_1905.dropna(inplace = True)

variaxis_2705 = pd.read_csv('Variaxis/2025-05-27_201.csv', low_memory=False)
variaxis_2705 = variaxis_2705[[col_time, col_tem, col_hum, col_vol, col_cor1, col_cor2, col_cor3]]
variaxis_2705.dropna(inplace = True)

variaxis_2506 = pd.read_csv('Variaxis/2025-06-25_201.csv', low_memory=False)
variaxis_2506 = variaxis_2506[[col_time, col_tem, col_hum, col_vol, col_cor1, col_cor2, col_cor3]]
variaxis_2506.dropna(inplace = True)

variaxis_0107 = pd.read_csv('Variaxis/2025-07-01_201.csv', low_memory=False)
variaxis_0107 = variaxis_0107[[col_time, col_tem, col_hum, col_vol, col_cor1, col_cor2, col_cor3]]
variaxis_0107.dropna(inplace = True)

variaxis_0907 = pd.read_csv('Variaxis/2025-07-09_201.csv', low_memory=False)
variaxis_0907 = variaxis_0907[[col_time, col_tem, col_hum, col_vol, col_cor1, col_cor2, col_cor3]]
variaxis_0907.dropna(inplace = True)


variaxis = pd.concat([
    variaxis_0304, variaxis_1104, variaxis_1404,
    variaxis_2204, variaxis_3004, variaxis_0805,
    variaxis_1605, variaxis_1905, variaxis_2705,
    variaxis_2705, variaxis_2506, variaxis_0107,
    variaxis_0907
])
variaxis.rename(columns = nuevas_cols, inplace = True)

# %% [markdown]
# ### Integrex (#13)

# %%
col_time = "/SEDE-NL/MANUFACTURA/MAZAK-INTEGREX-100/IIOT-13/MONITORING/TEMPERATURE/TIMESTAMP"
col_tem = "/SEDE-NL/MANUFACTURA/MAZAK-INTEGREX-100/IIOT-13/MONITORING/TEMPERATURE/VALUE"
col_hum = "/SEDE-NL/MANUFACTURA/MAZAK-INTEGREX-100/IIOT-13/MONITORING/HUMIDITY/VALUE"
col_vol = "/SEDE-NL/MANUFACTURA/MAZAK-INTEGREX-100/IIOT-13/MONITORING/VOLTAGE/VALUE"
col_cor1 = "/SEDE-NL/MANUFACTURA/MAZAK-INTEGREX-100/IIOT-13/MONITORING/CURRENT_1/VALUE"
col_cor2 = "/SEDE-NL/MANUFACTURA/MAZAK-INTEGREX-100/IIOT-13/MONITORING/CURRENT_2/VALUE"
col_cor3 = "/SEDE-NL/MANUFACTURA/MAZAK-INTEGREX-100/IIOT-13/MONITORING/CURRENT_3/VALUE"

nuevas_cols = {col_time: 'Fecha', col_tem: 'Temperatura', col_hum: 'Humedad', col_vol: 'Voltaje',
               col_cor1: 'Corriente_1', col_cor2: 'Corriente_2', col_cor3: 'Corriente_3'}

# %%
integrex_0805 = pd.read_csv('Integrex/2025-05-08_203.csv', low_memory=False)
integrex_0805 = integrex_0805[[col_time, col_tem, col_hum, col_vol, col_cor1, col_cor2, col_cor3]]
integrex_0805.dropna(inplace = True)

integrex_1605 = pd.read_csv('Integrex/2025-05-16_203.csv', low_memory=False)
integrex_1605 = integrex_1605[[col_time, col_tem, col_hum, col_vol, col_cor1, col_cor2, col_cor3]]
integrex_1605.dropna(inplace = True)

integrex_2005 = pd.read_csv('Integrex/2025-05-20_203.csv', low_memory=False)
integrex_2005 = integrex_2005[[col_time, col_tem, col_hum, col_vol, col_cor1, col_cor2, col_cor3]]
integrex_2005.dropna(inplace = True)

integrex_2705 = pd.read_csv('Integrex/2025-05-27_203.csv', low_memory=False)
integrex_2705 = integrex_2705[[col_time, col_tem, col_hum, col_vol, col_cor1, col_cor2, col_cor3]]
integrex_2705.dropna(inplace = True)

integrex_0907 = pd.read_csv('Integrex/2025-07-09_203.csv', low_memory=False)
integrex_0907 = integrex_0907[[col_time, col_tem, col_hum, col_vol, col_cor1, col_cor2, col_cor3]]
integrex_0907.dropna(inplace = True)


integrex = pd.concat([
    integrex_0805, integrex_1605, integrex_2005,
    integrex_2705, integrex_0907
])
integrex.rename(columns=nuevas_cols, inplace=True)

# %% [markdown]
# ### HASS (#12)

# %%
col_time = "/SEDE-NL/MANUFACTURA/HAAS-TORNO/IIOT-12/MONITORING/TEMPERATURE/TIMESTAMP"
col_tem = "/SEDE-NL/MANUFACTURA/HAAS-TORNO/IIOT-12/MONITORING/TEMPERATURE/VALUE"
col_hum = "/SEDE-NL/MANUFACTURA/HAAS-TORNO/IIOT-12/MONITORING/HUMIDITY/VALUE"
col_vol = "/SEDE-NL/MANUFACTURA/HAAS-TORNO/IIOT-12/MONITORING/VOLTAGE/VALUE"
col_cor1 = "/SEDE-NL/MANUFACTURA/HAAS-TORNO/IIOT-12/MONITORING/CURRENT_1/VALUE"
col_cor2 = "/SEDE-NL/MANUFACTURA/HAAS-TORNO/IIOT-12/MONITORING/CURRENT_2/VALUE"
col_cor3 = "/SEDE-NL/MANUFACTURA/HAAS-TORNO/IIOT-12/MONITORING/CURRENT_3/VALUE"

nuevas_cols = {col_time: 'Fecha', col_tem: 'Temperatura', col_hum: 'Humedad', col_vol: 'Voltaje',
               col_cor1: 'Corriente_1', col_cor2: 'Corriente_2', col_cor3: 'Corriente_3'}

# %%
haas_0905 = pd.read_csv('Haas/2025-05-09_202.csv', low_memory = False)
haas_0905 = haas_0905[[col_time, col_tem, col_hum, col_vol, col_cor1, col_cor2, col_cor3]]
haas_0905.dropna(inplace = True)

haas_1605 = pd.read_csv('Haas/2025-05-16_202.csv', low_memory = False)
haas_1605 = haas_1605[[col_time, col_tem, col_hum, col_vol, col_cor1, col_cor2, col_cor3]]
haas_1605.dropna(inplace = True)

haas_1905 = pd.read_csv('Haas/2025-05-19_202.csv', low_memory = False)
haas_1905 = haas_1905[[col_time, col_tem, col_hum, col_vol, col_cor1, col_cor2, col_cor3]]
haas_1905.dropna(inplace = True)

haas_2705 = pd.read_csv('Haas/2025-05-27_202.csv', low_memory = False)
haas_2705 = haas_2705[[col_time, col_tem, col_hum, col_vol, col_cor1, col_cor2, col_cor3]]
haas_2705.dropna(inplace = True)

haas_2506 = pd.read_csv('Haas/2025-06-25_202.csv', low_memory = False)
haas_2506 = haas_2506[[col_time, col_tem, col_hum, col_vol, col_cor1, col_cor2, col_cor3]]
haas_2506.dropna(inplace = True)

haas_0107 = pd.read_csv('Haas/2025-07-01_202.csv', low_memory = False)
haas_0107 = haas_0107[[col_time, col_tem, col_hum, col_vol, col_cor1, col_cor2, col_cor3]]
haas_0107.dropna(inplace = True)


haas = pd.concat([
    haas_0905, haas_1605, haas_1905,
    haas_2705, haas_2506, haas_0107
])
haas.rename(columns=nuevas_cols, inplace=True)

# %% [markdown]
# ### Compresor Kaeser (#10)

# %%
col_time = "/SEDE-NL/MANUFACTURA/KAESER-COMPRESOR/IIOT-10/MONITORING/TEMPERATURE/TIMESTAMP"
col_tem = "/SEDE-NL/MANUFACTURA/KAESER-COMPRESOR/IIOT-10/MONITORING/TEMPERATURE/VALUE"
col_hum = "/SEDE-NL/MANUFACTURA/KAESER-COMPRESOR/IIOT-10/MONITORING/HUMIDITY/VALUE"
col_vol = "/SEDE-NL/MANUFACTURA/KAESER-COMPRESOR/IIOT-10/MONITORING/VOLTAGE/VALUE"
col_cor1 = "/SEDE-NL/MANUFACTURA/KAESER-COMPRESOR/IIOT-10/MONITORING/CURRENT_1/VALUE"
col_cor2 = "/SEDE-NL/MANUFACTURA/KAESER-COMPRESOR/IIOT-10/MONITORING/CURRENT_2/VALUE"
col_cor3 = "/SEDE-NL/MANUFACTURA/KAESER-COMPRESOR/IIOT-10/MONITORING/CURRENT_3/VALUE"

nuevas_cols = {col_time: 'Fecha', col_tem: 'Temperatura', col_hum: 'Humedad', col_vol: 'Voltaje',
               col_cor1: 'Corriente_1', col_cor2: 'Corriente_2', col_cor3: 'Corriente_3'}

# %%
compresor_0304 = pd.read_csv('Compresor/2025-04-03_200.csv', low_memory = False)
compresor_0304 = compresor_0304[[col_time, col_tem, col_hum, col_vol, col_cor1, col_cor2, col_cor3]]
compresor_0304.dropna(inplace = True)

compresor_1104 = pd.read_csv('Compresor/2025-04-11_200.csv', low_memory = False)
compresor_1104 = compresor_1104[[col_time, col_tem, col_hum, col_vol, col_cor1, col_cor2, col_cor3]]
compresor_1104.dropna(inplace = True)

compresor_1404 = pd.read_csv('Compresor/2025-04-14_200.csv', low_memory = False)
compresor_1404 = compresor_1404[[col_time, col_tem, col_hum, col_vol, col_cor1, col_cor2, col_cor3]]
compresor_1404.dropna(inplace = True)

compresor_2204 = pd.read_csv('Compresor/2025-04-22_200.csv', low_memory = False)
compresor_2204 = compresor_2204[[col_time, col_tem, col_hum, col_vol, col_cor1, col_cor2, col_cor3]]
compresor_2204.dropna(inplace = True)

compresor_3004 = pd.read_csv('Compresor/2025-04-30_200.csv', low_memory = False)
compresor_3004 = compresor_3004[[col_time, col_tem, col_hum, col_vol, col_cor1, col_cor2, col_cor3]]
compresor_3004.dropna(inplace = True)

compresor_0805 = pd.read_csv('Compresor/2025-05-08_200.csv', low_memory = False)
compresor_0805 = compresor_0805[[col_time, col_tem, col_hum, col_vol, col_cor1, col_cor2, col_cor3]]
compresor_0805.dropna(inplace = True)

compresor_1605 = pd.read_csv('Compresor/2025-05-16_200.csv', low_memory = False)
compresor_1605 = compresor_1605[[col_time, col_tem, col_hum, col_vol, col_cor1, col_cor2, col_cor3]]
compresor_1605.dropna(inplace = True)

compresor_1905 = pd.read_csv('Compresor/2025-05-19_200.csv', low_memory = False)
compresor_1905 = compresor_1905[[col_time, col_tem, col_hum, col_vol, col_cor1, col_cor2, col_cor3]]
compresor_1905.dropna(inplace = True)

compresor_2705 = pd.read_csv('Compresor/2025-05-27_200.csv', low_memory = False)
compresor_2705 = compresor_2705[[col_time, col_tem, col_hum, col_vol, col_cor1, col_cor2, col_cor3]]
compresor_2705.dropna(inplace = True)

compresor_2506 = pd.read_csv('Compresor/2025-06-25_200.csv', low_memory = False)
compresor_2506 = compresor_2506[[col_time, col_tem, col_hum, col_vol, col_cor1, col_cor2, col_cor3]]
compresor_2506.dropna(inplace = True)

compresor_0107 = pd.read_csv('Compresor/2025-07-01_200.csv', low_memory = False)
compresor_0107 = compresor_0107[[col_time, col_tem, col_hum, col_vol, col_cor1, col_cor2, col_cor3]]
compresor_0107.dropna(inplace = True)

compresor_0907 = pd.read_csv('Compresor/2025-07-09_200.csv', low_memory = False)
compresor_0907 = compresor_0907[[col_time, col_tem, col_hum, col_vol, col_cor1, col_cor2, col_cor3]]
compresor_0907.dropna(inplace = True)


compresor = pd.concat([
    compresor_0304, compresor_1104, compresor_1404,
    compresor_2204, compresor_3004, compresor_0805,
    compresor_1605, compresor_1905, compresor_2705,
    compresor_2506, compresor_0107, compresor_0907
])
compresor.rename(columns=nuevas_cols, inplace=True)

# %% [markdown]
# ### Subestación N.L. (#9)

# %%
col_time = "/SEDE-NL/MANUFACTURA/SUBSTATION-NL/IIOT-9/MONITORING/TEMPERATURE/TIMESTAMP"
col_tem = "/SEDE-NL/MANUFACTURA/SUBSTATION-NL/IIOT-9/MONITORING/TEMPERATURE/VALUE"
col_hum = "/SEDE-NL/MANUFACTURA/SUBSTATION-NL/IIOT-9/MONITORING/HUMIDITY/VALUE"
col_vol = "/SEDE-NL/MANUFACTURA/SUBSTATION-NL/IIOT-9/MONITORING/VOLTAGE-RMS/VALUE"
col_cor1 = "/SEDE-NL/MANUFACTURA/SUBSTATION-NL/IIOT-9/MONITORING/CURRENT_1/VALUE"
col_cor2 = "/SEDE-NL/MANUFACTURA/SUBSTATION-NL/IIOT-9/MONITORING/CURRENT_2/VALUE"
col_cor3 = "/SEDE-NL/MANUFACTURA/SUBSTATION-NL/IIOT-9/MONITORING/CURRENT_3/VALUE"

nuevas_cols = {col_time: 'Fecha', col_tem: 'Temperatura', col_hum: 'Humedad', col_vol: 'Voltaje',
               col_cor1: 'Corriente_1', col_cor2: 'Corriente_2', col_cor3: 'Corriente_3'}

# %%
subestacion_1104 = pd.read_csv('Subestacion/2025-04-11_304.csv', low_memory = False)
subestacion_1104 = subestacion_1104[[col_time, col_tem, col_hum, col_vol, col_cor1, col_cor2, col_cor3]]
subestacion_1104.dropna(inplace = True)

subestacion_1404 = pd.read_csv('Subestacion/2025-04-14_304.csv', low_memory = False)
subestacion_1404 = subestacion_1404[[col_time, col_tem, col_hum, col_vol, col_cor1, col_cor2, col_cor3]]
subestacion_1404.dropna(inplace = True)

subestacion_2204 = pd.read_csv('Subestacion/2025-04-22_304.csv', low_memory = False)
subestacion_2204 = subestacion_2204[[col_time, col_tem, col_hum, col_vol, col_cor1, col_cor2, col_cor3]]
subestacion_2204.dropna(inplace = True)

subestacion_3004 = pd.read_csv('Subestacion/2025-04-30_304.csv', low_memory = False)
subestacion_3004 = subestacion_3004[[col_time, col_tem, col_hum, col_vol, col_cor1, col_cor2, col_cor3]]
subestacion_3004.dropna(inplace = True)

subestacion_0805 = pd.read_csv('Subestacion/2025-05-08_304.csv', low_memory = False)
subestacion_0805 = subestacion_0805[[col_time, col_tem, col_hum, col_vol, col_cor1, col_cor2, col_cor3]]
subestacion_0805.dropna(inplace = True)

subestacion_1605 = pd.read_csv('Subestacion/2025-05-16_304.csv', low_memory = False)
subestacion_1605 = subestacion_1605[[col_time, col_tem, col_hum, col_vol, col_cor1, col_cor2, col_cor3]]
subestacion_1605.dropna(inplace = True)

subestacion_1905 = pd.read_csv('Subestacion/2025-05-19_304.csv', low_memory = False)
subestacion_1905 = subestacion_1905[[col_time, col_tem, col_hum, col_vol, col_cor1, col_cor2, col_cor3]]
subestacion_1905.dropna(inplace = True)

subestacion_2605 = pd.read_csv('Subestacion/2025-05-26_304.csv', low_memory = False)
subestacion_2605 = subestacion_2605[[col_time, col_tem, col_hum, col_vol, col_cor1, col_cor2, col_cor3]]
subestacion_2605.dropna(inplace = True)

subestacion = pd.concat([
    subestacion_1104, subestacion_1404, subestacion_2204,
    subestacion_3004, subestacion_0805, subestacion_1605,
    subestacion_1905, subestacion_2605
])
subestacion.rename(columns=nuevas_cols, inplace=True)

# %% [markdown]
# ### ESP32-1

# %%
col_time = "datetime"
col_tem = "/SEDE-NL/METROLOGÍA/ESP32-IIOT-1/LAB-ELECTRICA/MONITORING/TEMPERATURE"
col_hum = "/SEDE-NL/METROLOGÍA/ESP32-IIOT-1/LAB-ELECTRICA/MONITORING/HUMIDITY"

nuevas_cols = {col_time : 'Fecha', col_tem : 'Temperatura', col_hum : 'Humedad'}

# %%
esp1_1605 = pd.read_csv('ESP32-1/2025-05-16_301.csv', low_memory=False)
esp1_1605 = esp1_1605[[col_time, col_tem, col_hum]]
esp1_1605.dropna(inplace=True)

esp1_1905 = pd.read_csv('ESP32-1/2025-05-19_301.csv', low_memory=False)
esp1_1905 = esp1_1905[[col_time, col_tem, col_hum]]
esp1_1905.dropna(inplace=True)

esp1_2705 = pd.read_csv('ESP32-1/2025-05-27_301.csv', low_memory=False)
esp1_2705 = esp1_2705[[col_time, col_tem, col_hum]]
esp1_2705.dropna(inplace=True)

esp1_1906 = pd.read_csv('ESP32-1/2025-06-19_301.csv', low_memory=False)
esp1_1906 = esp1_1906[[col_time, col_tem, col_hum]]
esp1_1906.dropna(inplace=True)

esp1_2306 = pd.read_csv('ESP32-1/2025-06-23_301.csv', low_memory=False)
esp1_2306 = esp1_2306[[col_time, col_tem, col_hum]]
esp1_2306.dropna(inplace=True)

esp1_0107 = pd.read_csv('ESP32-1/2025-07-01_301.csv', low_memory=False)
esp1_0107 = esp1_0107[[col_time, col_tem, col_hum]]
esp1_0107.dropna(inplace=True)

esp1_0907 = pd.read_csv('ESP32-1/2025-07-09_301.csv', low_memory=False)
esp1_0907 = esp1_0907[[col_time, col_tem, col_hum]]
esp1_0907.dropna(inplace=True)

esp1 = pd.concat([
    esp1_1605, esp1_1905, esp1_2705,
    esp1_1906, esp1_2306, esp1_0107,
    esp1_0907
])
esp1.rename(columns=nuevas_cols, inplace=True)

# %% [markdown]
# ### ESP32-2

# %%
col_time = "datetime"
col_tem = "/SEDE-NL/METROLOGÍA/ESP32-IIOT-2/LAB-ELECTRICA/MONITORING/TEMPERATURE"
col_hum = "/SEDE-NL/METROLOGÍA/ESP32-IIOT-2/LAB-ELECTRICA/MONITORING/HUMIDITY"

nuevas_cols = {col_time : 'Fecha', col_tem : 'Temperatura', col_hum : 'Humedad'}

# %%
esp2_1405 = pd.read_csv('ESP32-2/2025-05-14_302.csv', low_memory=False)
esp2_1405 = esp2_1405[[col_time, col_tem, col_hum]]
esp2_1405.dropna(inplace=True)

esp2_1905 = pd.read_csv('ESP32-2/2025-05-19_302.csv', low_memory=False)
esp2_1905 = esp2_1905[[col_time, col_tem, col_hum]]
esp2_1905.dropna(inplace=True)

esp2_2705 = pd.read_csv('ESP32-2/2025-05-27_302.csv', low_memory=False)
esp2_2705 = esp2_2705[[col_time, col_tem, col_hum]]
esp2_2705.dropna(inplace=True)

esp2_1906 = pd.read_csv('ESP32-2/2025-06-19_302.csv', low_memory=False)
esp2_1906 = esp2_1906[[col_time, col_tem, col_hum]]
esp2_1906.dropna(inplace=True)

esp2_2306 = pd.read_csv('ESP32-2/2025-06-23_302.csv', low_memory=False)
esp2_2306 = esp2_2306[[col_time, col_tem, col_hum]]
esp2_2306.dropna(inplace=True)

esp2_0107 = pd.read_csv('ESP32-2/2025-07-01_302.csv', low_memory=False)
esp2_0107 = esp2_0107[[col_time, col_tem, col_hum]]
esp2_0107.dropna(inplace=True)

esp2_0907 = pd.read_csv('ESP32-2/2025-07-09_302.csv', low_memory=False)
esp2_0907 = esp2_0907[[col_time, col_tem, col_hum]]
esp2_0907.dropna(inplace=True)


esp2 = pd.concat([
    esp2_1405, esp2_1905, esp2_2705,
    esp2_1906, esp2_2306, esp2_0107,
    esp2_0907
])
esp2.rename(columns=nuevas_cols, inplace=True)

# %% [markdown]
# ### ESP32-3

# %%
col_time = "datetime"
col_tem = "/SEDE-NL/METROLOGÍA/ESP32-IIOT-3/LAB-ELECTRICA/MONITORING/TEMPERATURE"
col_hum = "/SEDE-NL/METROLOGÍA/ESP32-IIOT-3/LAB-ELECTRICA/MONITORING/HUMIDITY"

nuevas_cols = {col_time : 'Fecha', col_tem : 'Temperatura', col_hum : 'Humedad'}

# %%
esp3_1405 = pd.read_csv('ESP32-3/2025-05-14_303.csv', low_memory=False)
esp3_1405 = esp3_1405[[col_time, col_tem, col_hum]]
esp3_1405.dropna(inplace=True)

esp3_1905 = pd.read_csv('ESP32-3/2025-05-19_303.csv', low_memory=False)
esp3_1905 = esp3_1905[[col_time, col_tem, col_hum]]
esp3_1905.dropna(inplace=True)

esp3_2705 = pd.read_csv('ESP32-3/2025-05-27_303.csv', low_memory=False)
esp3_2705 = esp3_2705[[col_time, col_tem, col_hum]]
esp3_2705.dropna(inplace=True)

esp3_1906 = pd.read_csv('ESP32-3/2025-06-19_303.csv', low_memory=False)
esp3_1906 = esp3_1906[[col_time, col_tem, col_hum]]
esp3_1906.dropna(inplace=True)

esp3_2306 = pd.read_csv('ESP32-3/2025-06-23_303.csv', low_memory=False)
esp3_2306 = esp3_2306[[col_time, col_tem, col_hum]]
esp3_2306.dropna(inplace=True)

esp3_0107 = pd.read_csv('ESP32-3/2025-07-01_303.csv', low_memory=False)
esp3_0107 = esp3_0107[[col_time, col_tem, col_hum]]
esp3_0107.dropna(inplace=True)

esp3_0907 = pd.read_csv('ESP32-3/2025-07-09_303.csv', low_memory=False)
esp3_0907 = esp3_0907[[col_time, col_tem, col_hum]]
esp3_0907.dropna(inplace=True)


esp3 = pd.concat([
    esp3_1405, esp3_1905, esp3_2705,
    esp3_1906, esp3_2306, esp3_0107,
    esp3_0907
])
esp3.rename(columns=nuevas_cols, inplace=True)

# %% [markdown]
# ## Reseting Indexes

# %%
variaxis.reset_index(inplace = True, drop = True)
#nexus.reset_index(inplace = True, drop = True)
integrex.reset_index(inplace = True, drop = True)
haas.reset_index(inplace = True, drop = True)
compresor.reset_index(inplace = True, drop = True)
subestacion.reset_index(inplace = True, drop = True)
esp1.reset_index(inplace = True, drop = True)
esp2.reset_index(inplace = True, drop = True)
esp3.reset_index(inplace = True, drop = True)

# %% [markdown]
# ## Processing Time Data

# %%
# ------------------------- Converting date column to datetime -------------------------
variaxis['Fecha'] = pd.to_datetime(variaxis['Fecha'], format = 'mixed')
#nexus['Fecha'] = pd.to_datetime(nexus['Fecha'], format='mixed')
integrex['Fecha'] = pd.to_datetime(integrex['Fecha'], format='mixed')
haas['Fecha'] = pd.to_datetime(haas['Fecha'], format='mixed')
compresor['Fecha'] = pd.to_datetime(compresor['Fecha'], format='mixed')
subestacion['Fecha'] = pd.to_datetime(subestacion['Fecha'], format='mixed')
esp1['Fecha'] = pd.to_datetime(esp1['Fecha'], format='mixed')
esp2['Fecha'] = pd.to_datetime(esp2['Fecha'], format='mixed')
esp3['Fecha'] = pd.to_datetime(esp3['Fecha'], format='mixed')

# ------------------------- Creating new time columns -------------------------
variaxis['Mes'] = variaxis['Fecha'].dt.month
variaxis['Semana'] = variaxis['Fecha'].dt.isocalendar().week
variaxis['Dia'] = variaxis['Fecha'].dt.day_name()
variaxis['Hora'] = variaxis['Fecha'].dt.hour

#nexus['Mes'] = variaxis['Fecha'].dt.month
#nexus['Semana'] = variaxis['Fecha'].dt.isocalendar().week
#nexus['Dia'] = variaxis['Fecha'].dt.day_name()
#nesus['Hora'] = variaxis['Fecha'].dt.hour

integrex['Mes'] = integrex['Fecha'].dt.month
integrex['Semana'] = integrex['Fecha'].dt.isocalendar().week
integrex['Dia'] = integrex['Fecha'].dt.day_name()
integrex['Hora'] = integrex['Fecha'].dt.hour

haas['Mes'] = haas['Fecha'].dt.month
haas['Semana'] = haas['Fecha'].dt.isocalendar().week
haas['Dia'] = haas['Fecha'].dt.day_name()
haas['Hora'] = haas['Fecha'].dt.hour

compresor['Mes'] = compresor['Fecha'].dt.month
compresor['Semana'] = compresor['Fecha'].dt.isocalendar().week
compresor['Dia'] = compresor['Fecha'].dt.day_name()
compresor['Hora'] = compresor['Fecha'].dt.hour

subestacion['Mes'] = subestacion['Fecha'].dt.month
subestacion['Semana'] = subestacion['Fecha'].dt.isocalendar().week
subestacion['Dia'] = subestacion['Fecha'].dt.day_name()
subestacion['Hora'] = subestacion['Fecha'].dt.hour

esp1['Mes'] = esp1['Fecha'].dt.month
esp1['Semana'] = esp1['Fecha'].dt.isocalendar().week
esp1['Dia'] = esp1['Fecha'].dt.day_name()
esp1['Hora'] = esp1['Fecha'].dt.hour

esp2['Mes'] = esp2['Fecha'].dt.month
esp2['Semana'] = esp2['Fecha'].dt.isocalendar().week
esp2['Dia'] = esp2['Fecha'].dt.day_name()
esp2['Hora'] = esp2['Fecha'].dt.hour

esp3['Mes'] = esp3['Fecha'].dt.month
esp3['Semana'] = esp3['Fecha'].dt.isocalendar().week
esp3['Dia'] = esp3['Fecha'].dt.day_name()
esp3['Hora'] = esp3['Fecha'].dt.hour


# ------------------------- Modifying columns types to string -------------------------
variaxis['Mes'] = variaxis['Mes'].astype(str)
variaxis['Hora'] = variaxis['Hora'].astype(str)

#nexus['Mes'] = nexus['Mes'].astype(str)
#nexus['Hora'] = nexus['Hora'].astype(str)

integrex['Mes'] = integrex['Mes'].astype(str)
integrex['Hora'] = integrex['Hora'].astype(str)

haas['Mes'] = haas['Mes'].astype(str)
haas['Hora'] = haas['Hora'].astype(str)

compresor['Mes'] = compresor['Mes'].astype(str)
compresor['Hora'] = compresor['Hora'].astype(str)

subestacion['Mes'] = subestacion['Mes'].astype(str)
subestacion['Hora'] = subestacion['Hora'].astype(str)

esp1['Mes'] = esp1['Mes'].astype(str)
esp1['Hora'] = esp1['Hora'].astype(str)

esp2['Mes'] = esp2['Mes'].astype(str)
esp2['Hora'] = esp2['Hora'].astype(str)

esp3['Mes'] = esp3['Mes'].astype(str)
esp3['Hora'] = esp3['Hora'].astype(str)

# %%
variaxis
# Out:
#                             Fecha  Temperatura    Humedad     Voltaje  \
# 0      2025-04-03 07:59:59.657102         27.9  58.799999  237.384155
# 1      2025-04-03 08:00:00.397123         27.9  58.799999  237.775970
# 2      2025-04-03 08:00:00.928514         27.9  58.799999  238.358963
# 3      2025-04-03 08:00:01.460945         27.9  58.799999  238.315048
# 4      2025-04-03 08:00:01.994437         27.9  58.799999  238.000549
# ...                           ...          ...        ...         ...
# 650350 2025-07-09 12:11:07.205748         28.9  42.500000  232.759064
# 650351 2025-07-09 12:11:07.737043         28.9  42.500000  233.850586
# 650352 2025-07-09 12:11:08.266237         28.9  42.500000  234.207932
# 650353 2025-07-09 12:11:09.004888         28.9  42.500000  233.083725
# 650354 2025-07-09 12:11:09.538233         28.9  42.500000  232.430695
#
#         Corriente_1  Corriente_2  Corriente_3 Mes  Semana        Dia Hora
# ...

# %% [markdown]
# ## Exporting Data

# %%
variaxis.to_csv("Variaxis.csv", index = False)
#nexus.to_csv("Nexus.csv", index = False)
integrex.to_csv("Integrex.csv", index = False)
haas.to_csv("Haas.csv", index = False)
compresor.to_csv("Compresor.csv", index = False)
subestacion.to_csv("Subestacion.csv", index = False)
esp1.to_csv("ESP32_1.csv", index = False)
esp2.to_csv("ESP32_2.csv", index = False)
esp3.to_csv("ESP32_3.csv", index = False)
